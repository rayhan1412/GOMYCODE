# %%
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
import pandas as pd
newdata=pd.read_csv('data.csv')
newdata
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0          343         0       2
# 1             1           76         0       3
# 2             2          641         0       3
# 3             3          568         0       3
# 4             4          672         0       1
# ..          ...          ...       ...     ...
# 886         886           10         1       2
# 887         887           61         0       3
# 888         888          535         0       3
# 889         889          102         0       3
# 890         890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# ...

# %%
newdata.drop("Unnamed: 0",axis=1,inplace=True)
newdata
x=newdata.drop(["Survived", "Name",  "Ticket", "Embarked","Title"], axis=1)
y= newdata["Survived"]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)
newdata["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
dtree = tree.DecisionTreeClassifier()  
dtree.fit(x_train, y_train)   
y_pred=dtree.predict(x_test)   
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7597765363128491

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(30,20))
plot_tree(dtree,filled=True,feature_names=x.columns,proportion=True)
# Out:
# [Text(658.7852855960265, 1058.5894736842106, 'Sex <= 0.5\ngini = 0.469\nsamples = 100.0%\nvalue = [0.624, 0.376]'),
#  Text(301.8650662251656, 1001.3684210526317, 'Pclass <= 2.5\ngini = 0.39\nsamples = 35.4%\nvalue = [0.266, 0.734]'),
#  Text(125.64238410596028, 944.1473684210526, 'Age <= 2.5\ngini = 0.1\nsamples = 18.7%\nvalue = [0.053, 0.947]'),
#  Text(110.86092715231788, 886.9263157894737, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]'),
#  Text(140.42384105960267, 886.9263157894737, 'Fare <= 26.125\ngini = 0.087\nsamples = 18.5%\nvalue = [0.045, 0.955]'),
#  Text(110.86092715231788, 829.7052631578947, 'PassengerId <= 48.0\ngini = 0.198\nsamples = 6.3%\nvalue = [0.111, 0.889]'),
#  Text(96.07947019867551, 772.4842105263158, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]'),
#  Text(125.64238410596028, 772.4842105263158, 'Age <= 55.5\ngini = 0.165\nsamples = 6.2%\nvalue = [0.091, 0.909]'),
# ...

# %%
dtree = tree.DecisionTreeClassifier(splitter='best',max_depth=7,max_leaf_nodes=7)  
dtree.fit(x_train, y_train)   
y_pred=dtree.predict(x_test)   
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.8156424581005587

# %% [markdown]
# this accuracy is higher than the previous one

# %%
plt.figure(figsize=(30,20))
plot_tree(dtree,filled=True,feature_names=x.columns,proportion=True)
# Out:
# [Text(744.0, 978.48, 'Sex <= 0.5\ngini = 0.469\nsamples = 100.0%\nvalue = [0.624, 0.376]'),
#  Text(372.0, 761.0400000000001, 'Pclass <= 2.5\ngini = 0.39\nsamples = 35.4%\nvalue = [0.266, 0.734]'),
#  Text(186.0, 543.6, 'gini = 0.1\nsamples = 18.7%\nvalue = [0.053, 0.947]'),
#  Text(558.0, 543.6, 'Fare <= 23.35\ngini = 0.5\nsamples = 16.7%\nvalue = [0.504, 0.496]'),
#  Text(372.0, 326.1600000000001, 'gini = 0.484\nsamples = 13.3%\nvalue = [0.411, 0.589]'),
#  Text(744.0, 326.1600000000001, 'gini = 0.219\nsamples = 3.4%\nvalue = [0.875, 0.125]'),
#  Text(1116.0, 761.0400000000001, 'Pclass <= 1.5\ngini = 0.296\nsamples = 64.6%\nvalue = [0.82, 0.18]'),
#  Text(930.0, 543.6, 'gini = 0.461\nsamples = 14.0%\nvalue = [0.64, 0.36]'),
#  Text(1302.0, 543.6, 'Age <= 3.5\ngini = 0.227\nsamples = 50.6%\nvalue = [0.869, 0.131]'),
#  Text(1116.0, 326.1600000000001, 'SibSp <= 2.5\ngini = 0.444\nsamples = 1.7%\nvalue = [0.333, 0.667]'),
# ...

# %%
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics  
x=newdata.drop(["Survived", "Name",  "Ticket", "Embarked","Title"], axis=1)
y= newdata["Survived"]
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.3)

# %%
clf=RandomForestClassifier(n_estimators=10)  
clf.fit(x_train, y_train)  
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8619402985074627

# %%
clf=RandomForestClassifier(n_estimators=50)  
clf.fit(x_train, y_train)  
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8507462686567164

# %%
clf=RandomForestClassifier(n_estimators=100)  
clf.fit(x_train, y_train)  
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8544776119402985

# %% [markdown]
# the accuracies of these forest trees with different numbers of estimators are slightly different
